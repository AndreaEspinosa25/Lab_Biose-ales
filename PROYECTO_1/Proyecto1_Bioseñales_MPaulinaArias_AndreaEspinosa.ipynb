# %% [markdown]
# **Enfermedad de Parkinson**
#
# **Diagnóstico**
#
# En estadios tempranos el diagnóstico es difícil, se ha descrito que existe un margen de error diagnóstico del 5-10% en la EPI. Por lo anterior, se han creado varios criterios clínicos, entre los más utilizados están los descritos por el Banco de Cerebros de la Sociedad de Enfermedad de Parkinson del Reino Unido, los cuales se consideran que tienen una certeza diagnóstica del 90 %. Se identifican con base en estos criterios [1]:
#
# a) síntomas esenciales para el diagnóstico del síndrome parkinsoniano
#
# b) criterios de exclusión para el diagnóstico de la EPI
#
# c) criterios que apoyan el diagnóstico de la EPI
#
# **Diagnóstico clínicamente definitivo**
#
# Se considera que para el diagnóstico clínico definido se requiere:
#
# 1) Existencia por un año o más de los tres signos motores cardinales de la enfermedad, incluyendo temblor de reposo, rigidez y bradicinesia
#
# 2) Respuesta a la administración de levodopa, al menos en una dosis diaria de un gramo durante el transcurso de un mes, que produzca moderado o marcado grado de mejoría clínica (30 % de mejoría en Escala UPDRS) y duración de la mejoría de un año o más.
#
# **Escalas en la enfermedad de Parkinson:** Para medir la discapacidad en la EPI se han desarrollado escalas que evalúan la función motora, los síntomas no motores, la capacidad de autonomía del paciente, las complicaciones del tratamiento, los signos y síntomas asociados e incluso las fluctuaciones. La escala de valoración clínica más utilizada actualmente es la UPDRS (Unified Parkinson´s Disease Rating Scale: Escala Unificada para Estratificar la Enfermedad de Parkinson). Esta escala es la que se utiliza en la mayoría de los estudios clínicos, incluye la valoración de los signos motores y los no motores, al igual que fluctuaciones y complicaciones del tratamiento [1].
#
# **Neuroimagen**
#
# En la actualidad, los estudios de neuroimagen no confirman el diagnóstico, sin embargo, permiten diferenciar la EPI de otras formas de Parkinsonismo. La TAC es útil para identificar hidrocefalia normotensa o lesiones vasculares. La imagen por Resonancia Magnética (IRM) es normal en la EPI, aunque en algunos casos se observa hipointensidad de la pars compacta en la sustancia nigra (en T2). La IRM tiene mayor sensibilidad para detectar alteraciones en el parénquima cerebral y es el método de elección para estudiar los pacientes con EPI. En IRM de campo alto es posible demostrar la pars compacta y pars reticular de la sustancia nigra con secuencias de T2, FLAIR y eco gradiente rápido (GRASS), además se logran observar depósitos de hierro en estas estructuras. En el PET utilizando Fluorodopa se puede detectar la captación de la fulorodopa en los ganglios basales. Esta captación se va perdiendo en el curso de la evolución, a pesar de lo anterior, aún no se considera útil en el diagnóstico de la EPI [1].
#
# El diagnostico presenta dificultades debido a que este no presenta una prueba definitiva solo para la enfermedad del parkinson y es común confundir los sintomas con otras enferemdades que tienen sintomas de parkinsonismo, los cuales pueden no ser causados por la enfermedad de Parkinson [1]

# %% [markdown]
# **Enfermedad de Huntington**
#
# La enfermedad de Huntington es una afección hereditaria caracterizada por la degeneración progresiva de las células nerviosas en ciertas áreas del cerebro. Esta enfermedad provoca movimientos incontrolados, deterioro cognitivo y problemas emocionales. Los síntomas generalmente aparecen en la edad adulta, entre los 30 y 50 años, aunque en algunos casos pueden manifestarse en la juventud. La enfermedad se debe a mutaciones en el gen HTT y se hereda de manera autosómica dominante (significa que la afección genética ocurre cuando el niño hereda una sola copia de un gen mutado (cambiado) de uno de los padres) [2].
#
# Con el fin de establecer un diagnóstico preciso de la enfermedad de Huntington (SH), hay que basarse en los síntomas y signos clínicos de una persona que presenta confirmación de herencia autosómica dominante por parte de uno de sus progenitores. Inicialmente, es crucial obtener una historia clínica que incluya antecedentes patológicos familiares. El estándar actual consiste en la determinación del ADN, que evidencie una repetición de CAG de al menos 36 en el gen Huntingtina, localizado en el cromosoma 4 [2].
#
# Además, los estudios de imágenes, como la tomografía computarizada y la resonancia magnética, revelan una disminución gradual de los ganglios basales y una atrofia en las cortezas frontal y temporal. En el caso del diagnóstico prenatal, se puede llevar a cabo entre las semanas 10 y 12 de embarazo mediante una muestra de las vellosidades coriónicas, y entre las semanas 15 y 17 mediante amniocentesis. Este tipo de diagnóstico se recomienda especialmente a los padres que conocen su estado genético. En situaciones donde se confirme la presencia del gen Huntingtina en el embrión, se plantea la posibilidad de interrumpir el embarazo. En el proceso de diagnóstico diferencial, es esencial comparar los síntomas motores con otras patologías y establecer relaciones para discernir entre distintas enfermedades [2].
#
# Esta enfermedad presenta dificultades en su diagnóstico debido a que en la gran mayoría de los casos, la enfermedad se desarrolla en la edad adulta y suele ser de progresión lenta, los primeros síntomas pueden pasar inadvertidos para familiares y pacientes a lo largo de los años confundiéndose con problemas de aprendizaje, lo que retrasaría el tratamiento de la enfermedad (que solo es para mejorar la calidad de vida de la persona) [3].

# %% [markdown]
# **Esclerosis Lateral**
#
# La esclerosis lateral amiotrófica (ELA), también llamada la enfermedad de Lou Gehrig, es un trastorno neurológico, degenerativo y mortal que afecta las neuronas motoras ubicadas en la corteza frontal, el tronco encefálico y la médula espinal. La enfermedad tiene una amplia gama de presentación, generalmente comienza como debilidad muscular en una extremidad, cambios en el timbre de la voz o dificultad para deglutir, que progresa a debilidad generalizada y parálisis de los músculos respiratorios que conducen a la muerte por insuficiencia respiratoria [4].
#
# La ELA se diagnostica clínicamente. Las pruebas complementarias contribuyen a confirmar la sospecha diagnóstica y descartar otras patologías. Actualmente, establecer la certeza diagnóstica requiere la participación de ambas neuronas motoras, o la participación de las neuronas motoras inferiores en al menos dos de cuatro regiones (bulbar, cervical, torácica o lumbosacra), así como la exclusión de otras condiciones etiológicas [4].
#
# Un diagnóstico definitivo aún requiere una historia clínica, un examen neurológico y pruebas complementarias. La prueba más importante es el electromiograma (EMG), que revela una disminución leve en la conducción motora, con amplitud de potencial de acción reducida y denervación muscular aguda o en curso, como la presencia potencial de fibrilación y fasciculaciones en múltiples músculos en las regiones examinadas. Aunque los hallazgos en el EMG permiten distinguir las atrofias neurogénicas de las enfermedades musculares, algunos procesos miopáticos pueden producir confusión con la ELA, como la polimiositis crónica, la enfermedad de Pompe o la neuropatía motora multifocal con bloqueos de conducción. Tradicionalmente, las pruebas genéticas no han sido una parte rutinaria de la evaluación de la ELA. Si hay antecedentes familiares, se podrían considerar las pruebas genéticas para el diagnóstico presintomático [4].
#
# El diagnóstico de la ELA puede presentar dificultades por que esta puede ser mal diagnosticada y confundida con otras enfermedades neuromusculares debido a los sintomas que presenta, además aún no existe ninguna prueba patognomónica (prueba que permita obtener un hallazgos distintivo o característico de la enfermedad o afección y que se pueden usar para establecer un diagnóstico) que facilite el reconocimiento de esta [4].

# %% [markdown]
# **Detrend - Scipy**
#
# La función detrend de scipy permite eliminar las tendencias lineales de los datos, lo que permite que la solo quede la parte oscilatoria de la señal, haciendo que el análisis de la señal sea fácil de realizar. La eliminación de esta tendencia se puede interpretar como la resta de un polinomio de ajustes de mínimos cuadrados [5].
#
# Desde una vista matemática se tiene que [6]:
# Una serie temporal se puede descomponer en tres componentes principales:
# - X(t): la serie observada en el tiempo t.
# - T(t): la tendencia.
# - S(t): los patrones estacionales o cíclicos.
# - R(t): el ruido o las fluctuaciones residuales (lo que queda una vez eliminada la tendencia y la estacionalidad).
#
# Esto se puede representar así [6]:
#
# X(t) = T(t) + S(t) + R(t)
#
# El objetivo es eliminar T(t), que es la tendencia, dejando S(t) + R(t).
# Luego, si se asume que la tendencia es una constante, es decir, simplemente la media de los datos. La fórmula básica sería [6]:
#
# Xdetrended(t) = X(t) - µ
#
# donde µ es la media de la serie:
#
# µ = 1/N(∑X(i))
#
# se resta la media de la serie temporal a cada valor de la serie. Esto desplaza los datos para que estén centrados alrededor de cero, eliminando una tendencia constante o estacionaria [6].
#
# Se asume que la tendencia sigue una línea recta, de la forma [6]:
#
# T(t) = a*t + b
#
# Donde [6]:
#
# a = es la pendiente de la tendencia lineal
#
# b = es la intersección en el eje y el valor inicial de la tendencia.
#
# Para eliminar la tendencia, se ajusta una línea recta a los datos. El proceso es buscar los coeficientes a y b que minimicen el error entre la serie observada X(t) y esta tendencia lineal [6].
#
# El error se minimiza a través del método de mínimos cuadrados:
#
# min∑(X(t)- (a*t + b))^2
#
# Una vez obtenemos a y b, restamos la tendencia de los datos:
#
# Xdetrended(t) = X(t) - (a*t + b)
#
# Este proceso remueve la tendencia lineal, dejando las fluctuaciones que ocurren alrededor de esta línea [6].

# %% [markdown]
# **El Filtro Hampel**
#
# Es un filtro no lineal de limpieza de datos que busca los valores atípicos o datos anormales locales en una secuencia temporal. Los valores atípicos son muy variados y por lo general son una “complicación importante” en el análisis de datos, razón por la cual es crucial considerar su origen; los errores de muestreo y los errores ajenos al muestreo (errores de reporte, errores sin respuesta y errores de selección de la muestra) son ejemplos de ello [7].
#
# El filtro Hampel busca los datos anormales locales en una secuencia temporal, estos valores son sustituidos por valores alternativos más razonables una vez encontrados; el algoritmo usa la Desviación de la Mediana Absoluta (MAD) en Series Temporales, es decir, utiliza la mediana de las observaciones vecinas como valor de referencia y el estimador de escala de MAD como medida alternativa de la distancia, en otras palabras, un punto de datos es declarado como valor atípico y puede ser sustituido si se encuentra a más de un número t de la escala de MAD estimada de la mediana respecto de sus vecinos, el valor de reemplazo utilizado en este procedimiento es la Mediana. Más específicamente, para cada observación en la secuencia de datos original; el filtro Hampel construye una ventana “móvil” que incluye los puntos K anteriores, el punto de datos de interés primario, y los puntos K subsiguientes de datos. El valor de referencia utilizado para el punto central de datos es la Mediana de estos 2k+1 observaciones sucesivas, y la estimación escala MAD se calcula a partir de estas mismas observaciones para servir como una medida de la "propagación natural local" de la secuencia de datos. Si el punto central de datos se encuentra a más de t valores de la estimación de la escala MAD de la mediana, es reemplazado por la Mediana, de lo contrario, se deja sin cambios [7].
#
# **formulación matematica [8]**
#
# Dada una secuencia x1, x2, x3, …, xn y una ventana deslizante de longitud k, defina las estimaciones de la mediana y la desviación estándar punto a punto mediante:
#
# Mediana local
#
# mi=median(xi−k,xi−k+1,xi−k+2,…,xi,…,xi+k−2,xi+k−1,xi+k)
#
# Desviación estándar
#
# σi=κmedian(∣xi−k−mi∣,…,∣xi+k−mi∣),
#
# donde κ=1/√2erf−1(1/2)≈1.4826
#
# La cantidad σi /κ se conoce como desviación absoluta media (MAD).
#
# Si una muestra xi es tal que
#
# ∣xi−mi∣>nσσi
#
# para un umbral dado nσ, el identificador de Hampel declara xi como un valor atípico y lo sustituye por mi.

# %% [markdown]
# **Entropía de permutación**
#
# La entropía de permutación es una medida de complejidad para series temporales y mide el grado de desorden en una serie temporal comparando el orden relativo de valores consecutivos. Esto se hace observando cómo cambian los valores vecinos en una serie de datos y determinando todas las permutaciones posibles para un conjunto de datos de una longitud específica (n).
# Esto tiene la ventaja de dar resultados significativos en presencia de ruido observacional y dinámico, además, es un método simple, de cálculo rápido y robusto. Para una serie de tiempo {𝑥𝑡 } = 1, . . . , 𝑇 , 𝜋 permutaciones de orden 𝑛, la PE se define por [9]:
#
# 𝐻(𝑛) = − ∑ 𝑝(𝜋)𝑙𝑜𝑔(𝑝(𝜋))
#
# Donde P(𝜋) es la frecuencia relativa de cada permutación 𝜋 dentro de la serie temporal. Este valor representa la cantidad de información contenida en la comparación de 𝑛 valores consecutivos de la serie. Un sistema completamente ordenado tendría una entropía de permutación baja, mientras que un sistema altamente caótico o aleatorio tendría una entropía más alta [9].
#
# En el ámbito de la bioingeniería es muy usada para el análisis de señales obtenidas por pruebas de ECG, EMG y EEG ya que permite obtener irregularidades en la dinámica de la señal, otro aplicativo es el uso de la EP para el estudio de las sub-bandas de señales obtenidas por medio de magnetoencefalografía (MEG) y encontrar características que sirven para la detección del deterioro cognitivo leve (MCI), también es usado para la caracterización de texturas en imágenes digitales. Hay estudios que muestran el uso de la EP para el estudio del efecto de la anestesia (efecto de un fármaco anestésico en las grabaciones de EEG al usar anestesia con sevoflurano). La EP es usada en diferentes áreas y tiene variedad de aplicativos incluso en el mercado económicos [10].

# %% [markdown]
# #CARGA DE DATOS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as signal
import seaborn as sns
from itertools import permutations
from scipy import stats  #Importar las funciones necesarias

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Organización de la información

# %%
import os
import re

#Se crean listas vacias para cada grupo
archivos_als = []
archivos_control = []
archivos_hunt = []
archivos_park = []

#Se crea una función que permita extraer el número que está en el nombre de cada archivo de los diferentes grupos
def extraer_numero(archivo):
    numeros = re.findall(r'\d+', archivo)
    return int(numeros[0]) if numeros else 0 #Si no encuentra ningún número devuelve el número 0


carpeta_origen = '/content/drive/MyDrive/neurodegenerative_disease_database'

#Se dividen los grupos en las listas vacias creadas anteriormente según el nombre del archivo
for archivo in os.listdir(carpeta_origen):
    if archivo.endswith('.ts'):
        if archivo.startswith('als'):
            archivos_als.append(archivo)
        elif archivo.startswith('control'):
            archivos_control.append(archivo)
        elif archivo.startswith('hunt'):
            archivos_hunt.append(archivo)
        elif archivo.startswith('park'):
            archivos_park.append(archivo)

#Se ordenan los archivos dentro de las listas en orden númerico ascedente gracias a la función de extracción de números
archivos_als = sorted(archivos_als, key=extraer_numero)
archivos_control = sorted(archivos_control, key=extraer_numero)
archivos_hunt = sorted(archivos_hunt, key=extraer_numero)
archivos_park = sorted(archivos_park, key=extraer_numero)


lista_total = []
lista_total.extend(archivos_control)
lista_total.extend(archivos_als)
lista_total.extend(archivos_hunt)
lista_total.extend(archivos_park)


print(lista_total)
# Out:
# ['control1.ts', 'control2.ts', 'control3.ts', 'control4.ts', 'control5.ts', 'control6.ts', 'control7.ts', 'control8.ts', 'control9.ts', 'control10.ts', 'control11.ts', 'control12.ts', 'control13.ts', 'control14.ts', 'control15.ts', 'control16.ts', 'als1.ts', 'als2.ts', 'als3.ts', 'als4.ts', 'als5.ts', 'als6.ts', 'als7.ts', 'als8.ts', 'als9.ts', 'als10.ts', 'als11.ts', 'als12.ts', 'als13.ts', 'hunt1.ts', 'hunt2.ts', 'hunt3.ts', 'hunt4.ts', 'hunt5.ts', 'hunt6.ts', 'hunt7.ts', 'hunt8.ts', 'hunt9.ts', 'hunt10.ts', 'hunt11.ts', 'hunt12.ts', 'hunt13.ts', 'hunt14.ts', 'hunt15.ts', 'hunt16.ts', 'hunt17.ts', 'hunt18.ts', 'hunt19.ts', 'hunt20.ts', 'park1.ts', 'park2.ts', 'park3.ts', 'park4.ts', 'park5.ts', 'park6.ts', 'park7.ts', 'park8.ts', 'park9.ts', 'park10.ts', 'park11.ts', 'park12.ts', 'park13.ts', 'park14.ts', 'park15.ts']

# %% [markdown]
# # Ejemplo de visualización de datos para tener en cuenta

# %%
carpeta_origen = '/content/drive/MyDrive/neurodegenerative_disease_database'

#Listado de columnas

names= ['Elapsed Time (sec)', 'Left Stride Interval (sec)', 'Right Stride Interval (sec)', 'Left Swing Interval (sec)',
'Right Swing Interval (sec)',	'Left Swing Interval (% of stride)', 'Right Swing Interval (% of stride)', 'Left Stance Interval (sec)', 'Right Stance Interval (sec)', 'Left Stance Interval (% of stride)',
'Right Stance Interval (% of stride)', 'Double Support Interval (sec)',	'Double Support Interval (% of stride)']


#Iterar sobre los archivos en una carpeta específica para visualizar
for archivo in archivos_als:

  ruta_completa = os.path.join(carpeta_origen, archivo)

  datos = pd.read_csv(ruta_completa, delimiter='\t', names=names)

  #Seleccionar las primeras 5 columnas
  datos_5 = datos.iloc[:, :5]

#Mostrar una muestra de las primeras 5 columnas
datos_5.head()
#Holi
#Como vas
# Out:
#    Elapsed Time (sec)  Left Stride Interval (sec)  \
# 0             22.8500                      1.4633
# 1             24.3333                      1.4833
# 2             25.7767                      1.4433
# 3             27.2133                      1.4367
# 4             28.6633                      1.4500
#
#    Right Stride Interval (sec)  Left Swing Interval (sec)  \
# 0                       1.4633                     0.4500
# 1                       1.5367                     0.4500
# 2                       1.4200                     0.4733
# 3                       1.4133                     0.4800
# 4                       1.4700                     0.4667
#
#    Right Swing Interval (sec)
# 0                      0.4567
# 1                      0.5567
# 2                      0.4933
# 3                      0.4600
# 4                      0.4900

# %% [markdown]
# # Hampel Filter

# %%
def hampel_filter(wk, K, FilterParams):

    Thresh = FilterParams[0] #Definir umbral de cambio

    ref = np.median(wk) #Calcular la mediana de la ventana wk

    #Calcular la desv absoluta media (MAD)
    AbsDev = np.abs(wk - ref)
    MAD = 1.4826 * np.median(AbsDev)  #Factor de escala para distribución normal

    #Valor de prueba para identificar outliers
    TestVal = np.abs(wk - ref)

    # Copia de wk para no modificar los datos originales
    yk = np.copy(wk)

    #Número de elementos que superan el umbral
    outliers = TestVal > (Thresh * MAD)
    numero = np.sum(outliers)  #Cantidad de outliers detectados
    #print("Número de outliers detectados:", numero)

    # Reemplazar los outliers por la mediana
    yk[outliers] = ref

    return yk

# %% [markdown]
# # Coeficiente de variación y desviación estándar

# %%
def funcionCVSD(data):
  SD = np.std(data)  # ddof=1 para muestra (desviación estándar muestral)
  CV = 100*(SD/np.mean(data)) if np.mean(data) != 0 else np.nan
  return CV, SD

# %% [markdown]
# # Entropía de permutación

# %%
#Delay entropia de permutación
def DataDelay(data, delay=1, dimension=3):
    if delay*dimension > len(data):
        raise NameError('No es posible')
    NuevoData = np.array([data[0:len(data)-delay*(dimension - 1)]])
    for i in range(1, dimension):
        NuevoData = np.append(NuevoData, [data[i*delay:len(data) - delay*(dimension - i - 1)]], axis=0)
    return NuevoData;
a = np.arange(0,3)
perms = set(permutations(a))

# %%
# Entropia de permutación
def permutacionEntropia(rank):
  PEd = 0
  for rank_pattern in perms:
    copy_rank = np.tile(rank_pattern,(rank[0].size,1))
    resultado = copy_rank.transpose() -rank
    total_pattern = np.shape(sum(np.abs(resultado),0))[0] - np.count_nonzero(sum(np.abs(resultado),0))
    if total_pattern != 0:
      PEd = PEd + (total_pattern/230)*np.log2(total_pattern/230)
  return PEd

# %% [markdown]
# # Visualización de una señal cruda, con detrending y filtrada con filtro Hampel

# %%
# Ruta completa del archivo
ruta_completa = os.path.join(carpeta_origen, 'control1.ts')

datos = pd.read_csv(ruta_completa, delimiter='\t', names=names)

#Valores de la primera columna para el tiempo.
tiempo = datos['Elapsed Time (sec)'].values

#columna a graficar
vals = datos['Left Stride Interval (sec)'].values

# Aplicar detrending a la columna
vals_detrended = signal.detrend(vals)

# Aplicar el filtro Hampel después del detrend
vals_filtrados = hampel_filter(vals_detrended, 3, [6])

# Graficación
plt.figure()
# original
plt.plot(tiempo, vals, label='Señal cruda')
# detrend
plt.plot(tiempo, vals_detrended, label='Señal al aplicar Detrend', color='purple')
# detrend y filtro de Hampel
plt.plot(tiempo, vals_filtrados, label='Señal al aplicar Detrend y Filtro Hampel', color='orange', linestyle='--')
plt.title('Comparación de señales')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Se comparan tres versiones de una señal a lo largo del tiempo.
#
# **1. Señal cruda**
#
#
# Muestra la fluctuación o tendencia inherente a los datos. Se observa la señal presenta una tendencia lineal creciente, además de algunos picos significativos.
#
#
# **2. Señal al aplicar Detrend**
#
# El detrend elimina cualquier tendencia lineal o de baja frecuencia en los datos, dando como resultado una señal más plana y centrada alrededor de un valor cercano a cero, eliminando las fluctuaciones de largo plazo que se observan en la señal cruda [5]. Sin embargo, aunque se haya removido la tendencia, todavía se observan algunos picos y posibles outliers.
#
# **3. Señal al aplicar Detrend y Filtro Hampel**
#
# El Filtro Hampel se usa para identificar y corregir los valores atípicos (outliers) que quedan en la señal [7]. Después de aplicar el filtro Hampel, los picos grandes y repentinos (como el que se ve cerca del punto 200) son suavizados o reemplazados por un valor más típico para evitar que los outliers distorsionen la señal.

# %% [markdown]
# # DataFrame con la información de todos los sujetos estudiados

# %%
vector_total = []
for archivo in lista_total:

    ruta_completa = os.path.join(carpeta_origen, archivo)

    datos = pd.read_csv(ruta_completa, delimiter='\t', names=names)

    #Valores de la primera columna para el tiempo.
    tiempo = datos['Elapsed Time (sec)'].values

    #Iterar solo sobre las columnas de interés (2, 3, 4 y 5)
    columnas_a_graficar = names[1:5]  # Selecciona las columnas por nombre

    # Parámetros del filtro de Hampel
    ventana = 3  # Tamaño de la ventana
    umbral = 6  # Umbral de outliers

    vector=[]
    for columna in columnas_a_graficar:
      valores = datos[columna].values

      # Aplicar detrending a la columna
      valores_detrended = signal.detrend(valores)

      # Aplicar el filtro Hampel después del detrend
      valores_filtrados = hampel_filter(valores_detrended, ventana, [umbral])

      #Cálculo CV, SD
      CV, SD = funcionCVSD(valores_filtrados)

      #Entropía
      desplazamiento=DataDelay(valores_filtrados)
      m_rank = np.argsort(desplazamiento, axis = 0, kind=None, order=None)
      entropia=permutacionEntropia(m_rank)
      vector.append(round(entropia,3))

      vector.append(CV)
      vector.append(SD)

    vector_total.append(vector)

df = pd.DataFrame(vector_total, columns=['Ent_LStride', 'CV_LStride', 'SD_LStride','Ent_RStride','CV_RStride','SD_RStride', 'Ent_LSwing', 'CV_LSwing', 'SD_LSwing', 'Ent_RSwing', 'CV_RSwing', 'SD_RSwing'])
df['Sujeto'] = lista_total
df['Condicion'] = df['Sujeto'].apply(lambda x: 'Control' if 'control' in x else 'ALS' if 'als' in x else 'Huntington' if 'hunt' in x else 'Parkinson')


#Reordenar las columnas para que 'Condicion' sea la primera
columnas = ['Condicion'] + [col for col in df.columns if col != 'Condicion']
df = df[columnas]

#Agregar la columna '#sujeto' con valores numéricos ascendentes
df['#sujeto'] = range(1, len(df) + 1)

#Reordenar las columnas para que 'Sujeto' sea la primera
columnas = ['Sujeto'] + [col for col in df.columns if col != 'Sujeto']
df = df[columnas]

#sujeto como índice
df.set_index('#sujeto',inplace=True)

# Configurar para mostrar todas las filas y columnas del DataFrame
pd.set_option('display.max_rows', None)  #Mostrar todas las filas
pd.set_option('display.max_columns', None)  #Mostrar todas las columnas
pd.set_option('display.width', None)  # Ajustar el ancho de la pantalla automáticamente
pd.set_option('display.max_colwidth', None)  #No truncar el contenido de las celdas

# Mostrar el DataFrame completo
df
# Out:
#                Sujeto   Condicion  Ent_LStride    CV_LStride  SD_LStride  Ent_RStride  \
# #sujeto
# 1         control1.ts     Control       -2.655 -2.766149e+03    0.034716       -2.700
# 2         control2.ts     Control       -2.604 -2.196941e+02    0.028789       -2.595
# 3         control3.ts     Control       -2.618  3.198422e+03    0.025309       -2.680
# 4         control4.ts     Control       -2.733 -8.249555e+02    0.012599       -2.723
# 5         control5.ts     Control       -2.667 -3.954542e+02    0.027663       -2.666
# 6         control6.ts     Control       -2.717  1.284964e+16    0.029324       -2.720
# 7         control7.ts     Control       -2.689 -5.690759e+02    0.020759       -2.712
# 8         control8.ts     Control       -2.655 -4.414755e+02    0.022685       -2.707
# 9         control9.ts     Control       -2.767 -8.561444e+02    0.027995       -2.764
# 10       control10.ts     Control       -2.762 -6.378665e+02    0.025906       -2.771
# ...

# %% [markdown]
# # Resultados y análisis

# %% [markdown]
# El análisis de este estudio se centra en comparar patrones de marcha en diferentes grupos: personas sanas (Control) y personas con tres enfermedades neurodegenerativas: Esclerosis Lateral Amiotrófica (ALS), Enfermedad de Huntington, y Enfermedad de Parkinson. La marcha, al ser un proceso motor controlado por el sistema nervioso central, puede verse alterada en personas con estas patologías [11], lo que hace que medir la variabilidad en la marcha ofrezca información valiosa sobre la severidad y naturaleza del deterioro motor en cada enfermedad.
#
# Para realizar esta comparación, se utilizaron tres métricas clave en las fases de paso (Stride) y balanceo (Swing), tanto en el lado izquierdo como en el derecho:
#
#
# *   Entropía (Ent): Evalúa el grado de desorden o imprevisibilidad en los patrones de marcha. Una entropía más alta refleja mayor desorganización o variabilidad [12].
#
# *   Coeficiente de Variación (CV): Mide la variabilidad relativa (normalizada) en los ciclos de marcha [13].
#
# * Desviación Estándar (SD): Mide la dispersión o variabilidad absoluta en los ciclos de marcha [13].
#
# Para facilitar la identificación de estos patrones, se realizan diferentes tipos de diagramas y pruebas de hipótesis.

# %% [markdown]
# # Diagramas de violín

# %% [markdown]
# Los diagramas de violín permiten visualizar la distribución completa de los datos en cada grupo para identificar patrones complejos como colas largas que indican una alta variabilidad en algunos individuos, los cuales permiten comprender la complejidad de la variabilidad en la marcha. Además, también se puede ver la concentración de los datos y evidenciar diferencias más sutiles en la dispersión y forma de distribuciones [14].
#
# Cada violín representa una distribución de datos, donde el ancho del violín indica la densidad de los datos en ese punto y la línea horizontal dentro del violín representa la media [14].

# %% [markdown]
# ###Para el coeficiente de variación

# %% [markdown]
# El **análisis de los coeficientes de variación (CV)** en las fases de paso (Stride) y balanceo (Swing) en los diferentes grupos de estudio ofrece una visión detallada de las diferencias en la marcha entre sujetos control y aquellos con enfermedades neurodegenerativas como ALS, Huntington y Parkinson. Para este análisis es importante tener en cuenta que los ejes Y de cada una de las gráficas tienen escala diferente.

# %%
enfermedades = ['Control', 'ALS', 'Huntington', 'Parkinson']

# Filtrar columnas que contienen 'CV'
columnas_cv = [col for col in df.columns if 'CV' in col]

# Establecer el tamaño de la figura
plt.figure(figsize=(20, 15))

# Crear un gráfico de violín para cada columna de CV, y por cada enfermedad
for i, columna in enumerate(columnas_cv, 1):
    for j, enfermedad in enumerate(enfermedades):
        plt.subplot(len(columnas_cv), len(enfermedades), (i - 1) * len(enfermedades) + j + 1)


        datos_filtrados = df[df['Condicion'] == enfermedad]


        sns.violinplot(x='Condicion', y=columna, data=datos_filtrados, inner=None, color="lightgray")

        # Superponer gráfico de caja y bigote
        sns.boxplot(x='Condicion', y=columna, data=datos_filtrados, width=0.2, showcaps=True, boxprops={'zorder': 2})


        plt.title(f'{columna} - {enfermedad}')
        plt.xlabel('Enfermedad')
        plt.ylabel(columna)

plt.tight_layout()
plt.show()

# %% [markdown]
# En general, se observa que las medias de las variables de marcha en los grupos con enfermedad se desvían significativamente de las medias del grupo control. Esto indica que los pacientes con estas enfermedades presentan patrones de marcha anormales. La dirección de estas desviaciones varía según la enfermedad y la variable específica, lo que sugiere que cada enfermedad afecta la marcha de manera diferente.
#
# En el grupo control, el coeficiente de variación es muy bajo tanto en la fase de paso como en la de balanceo, lo que indica una marcha altamente estable y regular. Esto es consistente con el comportamiento esperado en individuos sanos, cuyo ciclo de marcha presenta una mínima dispersión con respecto a la media, lo que refleja una alta consistencia en sus movimientos.
#
# En los pacientes con ALS, se observa un incremento en el coeficiente de variación en ambas fases de la marcha, especialmente en la fase de paso, y presentando valores atípicos significativamente distanciados de 0. La mayor parte de los valores se agrupan cerca de la media, lo que sugiere que, aunque existe un aumento en la variabilidad de la marcha, la mayoría de los pacientes con ALS todavía mantiene cierto grado de control motor [15]. Esto se refleja también en la fase de balanceo, donde la dispersión es mayor que en los controles, pero sigue siendo moderada en comparación con las otras enfermedades.
#
# Los pacientes con Huntington,  muestran un marcado incremento en la variabilidad, presentando más valores atípicos que los demás grupos. Esto sugiere una gran inestabilidad en la marcha, reflejando los movimientos involuntarios y la descoordinación motora características de la enfermedad, lo que subraya el impacto severo de la enfermedad de Huntington en el control del movimiento [2]. En términos de dispersión, Huntington es la condición más extrema de todas las analizadas.
#
# Finalmente, los pacientes con Parkinson presentan un coeficiente de variación que en general es mayor que los controles, pero menor en comparación con ALS y, especialmente, Huntington. La variabilidad es evidente tanto en la fase de paso como en la de balanceo, aunque los valores tienden a estar más concentrados alrededor de la media. Esto sugiere que, aunque los pacientes con Parkinson experimentan dificultades para mantener un ciclo de marcha estable, su variabilidad es más contenida en comparación con las otras enfermedades.

# %% [markdown]
# ## Para la desviación estándar

# %% [markdown]
# La desviación estándar es una medida de dispersión que indica qué tan dispersos están los datos con respecto a la media. En este contexto, una SD más alta significa una mayor variabilidad o diferencia entre las medidas de la marcha de un individuo a otro dentro de un mismo grupo [13]. Para este análisis es importante tener en cuenta que los ejes Y de cada una de las gráficas tienen escala diferente.

# %%
enfermedades = ['Control', 'ALS', 'Huntington', 'Parkinson']

# Filtrar columnas que contienen 'SD'
columnas_sd = [col for col in df.columns if 'SD' in col]

# Establecer el tamaño de la figura
plt.figure(figsize=(20, 15))

# Crear un gráfico de violín para cada columna de SD, y por cada enfermedad
for i, columna in enumerate(columnas_sd, 1):
    for j, enfermedad in enumerate(enfermedades):
        plt.subplot(len(columnas_sd), len(enfermedades), (i - 1) * len(enfermedades) + j + 1)

        datos_filtrados = df[df['Condicion'] == enfermedad]

        sns.violinplot(x='Condicion', y=columna, data=datos_filtrados, inner=None, color="lightgray")

        # Superponer gráfico de caja y bigote
        sns.boxplot(x='Condicion', y=columna, data=datos_filtrados, width=0.2, showcaps=True, boxprops={'zorder': 2})

        plt.title(f'{columna} - {enfermedad}')
        plt.xlabel('Enfermedad')
        plt.ylabel(columna)


plt.tight_layout()
plt.show()

# %% [markdown]
# En general, los violines de los grupos con enfermedad son más altos que los del grupo control. Esto indica que los pacientes con estas enfermedades presentan una mayor desviación estándar en las variables de la marcha, es decir, una mayor variabilidad en sus patrones de caminar. Una mayor desviación estándar sugiere una menor consistencia y repetibilidad en los movimientos de la marcha en estos pacientes.
#
# En el grupo de control, tanto el SD del paso como del balanceo presentan valores bajos (entre 0.01 - 0.05 y 0.005 - 0.03, respectivamente), con distribuciones simétricas y poca dispersión. Esto refleja una marcha estable y consistente, lo cual es esperable en individuos sanos.
#
# Por otro lado, en los pacientes con ALS, se observa una mayor dispersión en el SD del paso, con algunos individuos mostrando una variabilidad significativamente elevada (datos atípicos). A pesar de esto, la mayoría de los valores se agrupan cerca del centro, lo que indica que, aunque la marcha es menos regular que en los controles, la variabilidad no es extrema en la mayoría de los casos. Además, la fase de balanceo también presenta mayor variabilidad en comparación con los controles, aunque sigue siendo más controlada que en enfermedades como Huntington. Esto sugiere que, si bien la enfermedad afecta la marcha, los pacientes con ALS mantienen un cierto grado de estabilidad en su patrón de movimiento [15].
#
# En los pacientes con Huntington, las distribuciones del SD de paso son mucho más amplias, indicando una marcha altamente inestable. Algunos individuos presentan valores extremadamente altos, lo que refleja la naturaleza caótica y descoordinada de la marcha asociada con la enfermedad. Esta alta variabilidad también se extiende a la fase de balanceo, donde los pacientes con Huntington muestran una mayor inestabilidad en comparación con los grupos de ALS y Parkinson, lo cual es coherente con los movimientos involuntarios característicos de la enfermedad.
#
# Finalmente, los pacientes con Parkinson presentan un valor de DS mayor que los controles, pero con menos variabilidad en comparación con ALS y Huntington. Estos valores están más centrados, reflejando una mayor consistencia en la marcha, aunque todavía con dificultades para mantener un ciclo de paso fluido. La fase de balanceo en este grupo también muestra una mayor variabilidad que en los controles, pero la distribución está más ajustada, lo que sugiere que, aunque hay irregularidades en la marcha, los pacientes con Parkinson mantienen un control motor más predecible que en los casos de Huntington.
#
# Entonces se tiene que cada enfermedad tiene su patrón distintivo de alteración en la marcha [16], con Huntington mostrando los cambios más extremos, seguido de ALS y luego Parkinson.

# %% [markdown]
# ## Para la entropía

# %%
enfermedades = ['Control', 'ALS', 'Huntington', 'Parkinson']

#Se filtran las columnas que tengan los datos de entropía para los diferentes grupos (control y enfermedades)
columnas_ent = [col for col in df.columns if 'Ent' in col]


plt.figure(figsize=(20, 15))

#Se crea un gráfico de violin para el grupo de control y las diferentes enfermedades
for i, columna in enumerate(columnas_ent, 1):
    for j, enfermedad in enumerate(enfermedades):
        plt.subplot(len(columnas_ent), len(enfermedades), (i - 1) * len(enfermedades) + j + 1)


        datos_filtrados = df[df['Condicion'] == enfermedad]

        sns.violinplot(x='Condicion', y=columna, data=datos_filtrados, inner=None, color="lightgray")

        #Se crea un gráfico que superponga el diagrama de cajas y bigotes con el gráfico de violin
        sns.boxplot(x='Condicion', y=columna, data=datos_filtrados, width=0.2, showcaps=True, boxprops={'zorder': 2})

        plt.title(f'{columna} - {enfermedad}')
        plt.xlabel('Enfermedad')
        plt.ylabel(columna)


plt.tight_layout()
plt.show()

# %% [markdown]
# Los violines de los grupos con enfermedad, en general, muestran una mayor dispersión de los datos, lo que indica una mayor variabilidad en los patrones de marcha en comparación con el grupo control.
# La forma de los violines sugiere que las distribuciones pueden no ser completamente simétricas, lo que podría indicar la presencia de valores atípicos
#
# La posición de las medianas sugiere que los grupos con enfermedad tienen valores medios diferentes para la variable de marcha en comparación con el grupo control. Esto indica que hay diferencias significativas en los patrones de marcha entre los grupos. Además,la altura de los violines y la longitud de las cajas varían entre los grupos, lo que es un indicador de las diferencias en la variabilidad de los datos, es decir, indica que cada enfermedad neurodegenerativa afecta la marcha de manera diferente [16].
#
#
# En ALS, la entropía de todas las fases de marcha (LStride, RStride, LSwing, RSwing) tiene una mayor dispersión en comparación con el grupo de Control. Esto sugiere una mayor irregularidad o complejidad en el patrón de marcha de los pacientes con ALS en comparación con los controles sanos.
#
# Para Huntington, la entropía muestra una distribución más ancha que el grupo Control, pero menos extrema que ALS, aunque presenta mayor cantidad de outliers (valores atípicos). Esto indica que los pacientes con Huntington presentan un grado de irregularidad en la marcha, pero no tan severo como en ALS.
#
# Por último, el grupo de pacientes con enfermedad de Parkinson muestra una distribución de entropía con la mayor dispersión. Además, no hay valores atípicos claros en el grupo de Parkinson, lo que indica una menor variabilidad en comparación con los otros grupos patológicos.

# %% [markdown]
# #Pruebas de hipótesis

# %% [markdown]
# El análisis de las pruebas de hipótesis permite tomas decisiones estadísticas basadas en datos, con el fin de determinar si los resultados observados son significativos.
#
# La prueba de normalidad de realizó mediante la **prueba de Shapiro-Wilks** debido a que se trabajaron grupos caracterizados por tener menos de 50 muestras [17].
#
# Seguidamente, se realizó la **prueba de homocedasticidad de Levene** para verificar si varios grupos de datos tienen varianzas iguales. Esta prueba es más robusta que otras pruebas de homocedasticidad (como la prueba de Bartlett) cuando los datos no siguen una distribución normal, lo que la hace adecuada para este análisis [18].
#
# Por último, como no se cumple el supuesto de normalidad para ningún caso, y no se cumplen los de homocedasticidad en muchos casos, se opta por la realización de pruebas no paramétricas, en este caso, se emplea la **Prueba U de Mann-Whitney** para comparar si hay diferencias significativas entre las distribuciones de dos grupos independientes.  A diferencia de pruebas paramétricas como el t-test, la prueba de Mann-Whitney no requiere que los datos sigan una distribución normal, lo que la hace adecuada para este análisis [19].

# %%
#Se crea una función que permita la comparación de los diferentes grupos
def comparar_grupos(data1, data2, label1, label2, columna, normalidad_cumplida, homocedasticidad_cumplida):
    alpha = 0.05
    results = {}

    if normalidad_cumplida and homocedasticidad_cumplida:
        t_stat, t_p_value = stats.ttest_ind(data1, data2)
        results['t_stat'] = t_stat
        results['p_value'] = t_p_value
        results['conclusion'] = (t_p_value < alpha)
    else:
        #Ho = No hay diferencias significativas entre los grupos (pertecenen a una misma población)
        #Ha = Hay diferencias significativas entre los grupos (No pertenecen a una misma población)

        u_stat, u_p_value = stats.mannwhitneyu(data1, data2)
        results['u_stat'] = u_stat
        results['p_value'] = u_p_value
        results['conclusion'] = (u_p_value < alpha)

    results['Grupo 1'] = label1
    results['Grupo 2'] = label2
    return results

#Se crean diccionarios vacios donde se guardaran los datos obtenidos
resultados_normalidad = {}
resultados_homocedasticidad = {}
resultados_comparaciones = {}

#Se realiza un for que permita hacer cada una de las pruebas por cada columna
for columna in df.columns[2:]:


    groups = {condition: df[df['Condicion'] == condition][columna] for condition in df['Condicion'].unique()}

    # Prueba de normalidad

    #Ho= Los datos siguen una distribución normal
    #Ha= Los datos NO siguen una distribución normal
    normality_results = {condition: stats.shapiro(data)[1] for condition, data in groups.items()}
    normalidad_cumplida = all(p > 0.05 for p in normality_results.values())
    resultados_normalidad[columna] = 'Dist normal' if normalidad_cumplida else 'NO dist normal'

    # Prueba de homocedasticidad

    #Ho= La varianza es igual entre diferentes grupos (homocedasticidad)
    #Ha= La varianza NO es igual en los diferentes grupos (heterocedasticidad)
    p_levene = stats.levene(*groups.values())[1]
    homocedasticidad_cumplida = p_levene > 0.05
    resultados_homocedasticidad[columna] = 'Hay homocedasticidad' if homocedasticidad_cumplida else 'Hay heterocedasticidad'

    #Se compara los resultados entre los diferentes grupos
    comparaciones = []
    for i in range(len(groups)):
        for j in range(i + 1, len(groups)):
            label1, label2 = list(groups.keys())[i], list(groups.keys())[j]
            resultados = comparar_grupos(groups[label1], groups[label2], label1, label2, columna, normalidad_cumplida, homocedasticidad_cumplida)
            comparaciones.append(resultados)

    #Se crea un dataFrame de los datos obtenidos de las diferentes comparaciones
    resultados_comparaciones[columna] = pd.DataFrame(comparaciones)

#Se convierten estos resultados en dataFrame
df_normalidad = pd.DataFrame.from_dict(resultados_normalidad, orient='index', columns=['Conclusión'])
df_homocedasticidad = pd.DataFrame.from_dict(resultados_homocedasticidad, orient='index', columns=['Conclusión'])
df_comparaciones = {columna: df for columna, df in resultados_comparaciones.items()}

#Se crea un for que permita reemplazar el valor booleano por una string que indique la conclusión o resultado de la comparación analizada
for columna, df in df_comparaciones.items():
    df['conclusion'] = df['conclusion'].replace({True: 'Dif SIGNFICATIVA', False: 'NO significativa'})

#Se muestran los resultados
print("\nResultados de Normalidad:")
print(df_normalidad)

print("\nResultados de Homocedasticidad:")
print(df_homocedasticidad)

for columna, df in df_comparaciones.items():
    print(f"\nResultados de Comparaciones (Prueba U) para {columna}:")
    print(df[['Grupo 1', 'Grupo 2', 'p_value', 'conclusion']])
# Out:
# Resultados de Normalidad:
#                  Conclusión
# Ent_LStride  NO dist normal
# CV_LStride   NO dist normal
# SD_LStride   NO dist normal
# Ent_RStride  NO dist normal
# CV_RStride   NO dist normal
# SD_RStride   NO dist normal
# Ent_LSwing   NO dist normal
# CV_LSwing    NO dist normal
# SD_LSwing    NO dist normal
# Ent_RSwing   NO dist normal
# CV_RSwing    NO dist normal
# SD_RSwing    NO dist normal
#
# Resultados de Homocedasticidad:
#                          Conclusión
# Ent_LStride  Hay heterocedasticidad
# CV_LStride     Hay homocedasticidad
# SD_LStride     Hay homocedasticidad
# Ent_RStride    Hay homocedasticidad
# CV_RStride     Hay homocedasticidad
# SD_RStride     Hay homocedasticidad
# Ent_LSwing   Hay heterocedasticidad
# CV_LSwing      Hay homocedasticidad
# SD_LSwing      Hay homocedasticidad
# Ent_RSwing     Hay homocedasticidad
# CV_RSwing      Hay homocedasticidad
# SD_RSwing      Hay homocedasticidad
#
# ...

# %% [markdown]
# ### **1. Normalidad:**
#
# Los resultados muestran que ninguna de las variables evaluadas sigue una distribución normal. Esto implica que los métodos estadísticos paramétricos tradicionales no son apropiados para realizar comparaciones entre los grupos. En su lugar, se utilizan pruebas no paramétricas, como la prueba U de Mann-Whitney.
#
# ### **2. Homocedasticidad:**
# - **Entropía (Ent)** muestra **heterocedasticidad** en todas las mediciones (Stride y Swing), lo que indica que la varianza no es constante entre los grupos.
# - **Coeficiente de Variación (CV)** y **Desviación Estándar (SD)** muestran homocedasticidad, lo que hace referencia a varianzas constantes entre los grupos.
#
# La **heterocedasticidad** obtenida al evaluar la entropía puede ser un indicador de que diferentes grupos de enfermedades presentan variabilidades muy distintas en su marcha, lo cual es coherente con el comportamiento motor de enfermedades como Huntington o Parkinson, que pueden tener un patrón de marcha más errático [20].
#
# ### **3. Comparaciones entre Grupos (Prueba U de Mann-Whitney):**
#
#   Se analizan las características de entropía, CV y SD tanto en el lazo izquierdo como en el derecho (simetría de la marcha) para las fases de paso y balanceo.
#
# #### **Fase de paso (Stride)**
# - *Ent_LStride y Ent_RStride*
#
#     En ambas mediciones (izquierda y derecha), se observan **diferencias significativas** entre el grupo control y ALS, así como entre ALS con Huntington y Parkinson, lo que indica que la entropía en la fase de paso es un factor diferenciador entre estos grupos. Sin embargo, no se hallan diferencias significativas entre Huntington y Parkinson, lo que indica que, en cuanto a la entropía, Huntington y Parkinson tienen patrones similares en esta fase.
#
# - *SD_LStride y SD_RStride*
#
#     En ambas mediciones (izquierda y derecha), hay **diferencias significativas** entre el grupo control y los tres grupos de enfermedades (ALS, Huntington y Parkinson), lo que sugiere que la desviación estándar en la fase de paso distingue bien a los controles de las personas con enfermedades neurodegenerativas. Por otro lado, no hay diferencias significativas entre ALS con Huntington o Parkinson, lo que indica una variabilidad similar en la fase de paso entre estos grupos. Sin embargo, sí existe diferencia significativa entre Huntington y Parkinson en SD_RStride, lo que indica que el patrón de variabilidad en la pierna derecha puede ser más distintivo entre estos dos grupos.
#
# - *CV_LStride y CV_RStride*
#
#     El *coeficiente de variación (CV)* en la fase de *Stride* **no muestra diferencias significativas** entre los grupos en la mayoría de los casos, con la excepción de una diferencia significativa entre Huntington y Parkinson en la fase derecha (CV_RStride). Esto sugiere que, aunque las otras medidas (entropía y desviación estándar) diferencian a los grupos, el CV en sí no parece ser un diferenciador tan fuerte para la fase de *Stride*.
#
#
# #### **Fase de balanceo (Swing)**
#
#
# - *Ent_LSwing y Ent_RSwing*
#
#     De nuevo, hay **diferencias significativas** entre el grupo control y ALS, así como entre ALS con Huntington y Parkinson, tanto en la pierna izquierda como derecha en la fase de balanceo. Además, no se observan diferencias significativas entre Huntington y Parkinson ni entre el control con estos grupos, lo que implica que la entropía en la fase de balanceo sigue un patrón similar al de la fase de paso.
#
# - *SD_LSwing y SD_RSwing*
#
#     Al igual que en Stride, la desviación estándar en la fase de Swing muestra **diferencias significativas** entre el grupo control y los tres grupos de enfermedades neurodegenerativas. Sin embargo, no hay diferencias significativas entre ALS con Huntington o Parkinson, lo que sugiere que las enfermedades afectan de manera similar la variabilidad en la fase de Swing.
#
# - *CV_LSwing y CV_RSwing*
#
#     En la fase de Swing, el CV **tampoco muestra diferencias significativas** entre la mayoría de los grupos, similar a lo observado en Stride. Esto refuerza la idea de que el coeficiente de variación, como medida de dispersión, no es tan útil para distinguir entre los grupos como lo son la entropía o la desviación estándar.

# %% [markdown]
# # Gráfico de dispersión (Scatter plot) de Entropía vs Coeficiente de Variación

# %% [markdown]
# Como se obtuvieron resultados significativos sobre la entropía y la desviación estándar, se realiza un gráfico de dispersión para mostrar su relación en un solo gráfico y analizar si existe una correlación entre la imprevisibilidad de la marcha (entropía) y la variabilidad absoluta de los ciclos de marcha (SD) [21].

# %%
plt.figure(figsize=(12, 10))

#Se genera el gráfico de dispersión para LStride
plt.subplot(2, 2, 1)
sns.scatterplot(x='Ent_LStride', y='SD_LStride', hue='Condicion', data=df, palette='Set1')
plt.title('Entropía vs SD (LStride - Paso Izquierdo)')
plt.xlabel('Entropía (LStride)')
plt.ylabel('SD (LStride)')
plt.legend(loc='upper right')

#Se genera el gráfico de dispersión para RStride
plt.subplot(2, 2, 2)
sns.scatterplot(x='Ent_RStride', y='SD_RStride', hue='Condicion', data=df, palette='Set2')
plt.title('Entropía vs SD (RStride - Paso Derecho)')
plt.xlabel('Entropía (RStride)')
plt.ylabel('SD (RStride)')
plt.legend(loc='upper right')

#Se genera el gráfico de dispersión para LSwing
plt.subplot(2, 2, 3)
sns.scatterplot(x='Ent_LSwing', y='SD_LSwing', hue='Condicion', data=df, palette='Set3')
plt.title('Entropía vs SD (LSwing - Balanceo Izquierdo)')
plt.xlabel('Entropía (LSwing)')
plt.ylabel('SD (LSwing)')
plt.legend(loc='upper right')

#Se genera el gráfico de dispersión para RSwing
plt.subplot(2, 2, 4)
sns.scatterplot(x='Ent_RSwing', y='SD_RSwing', hue='Condicion', data=df, palette='Set1')
plt.title('Entropía vs SD (RSwing - Balanceo Derecho)')
plt.xlabel('Entropía (RSwing)')
plt.ylabel('SD (RSwing)')
plt.legend(loc='upper right')


plt.tight_layout()
plt.show()

# %% [markdown]
# 1. **Entropía vs SD (LStride - Paso Izquierdo):**
#
#     Se observa una agrupación clara de los datos de control con valores bajos de SD y entropía. Los pacientes con ALS y Huntington tienen mayor dispersión, lo que sugiere gran variabilidad en la marcha en estas enfermedades.
#
#
#
# 2. **Entropía vs SD (RStride - Paso Derecho):**
#
#     Se puede ver que el grupo con enfermedad de Huntington tiene mayor variabilidad en la desviación estándar, lo que puede estar relacionado con inestabilidades o dificultades en la marcha derecha en esta enfermedad
#
#
#
# 3. **Entropía vs SD (LSwing - Balanceo Izquierdo):**
#
#     Los pacientes con ALS y Huntington tienden a tener una mayor dispersión, nuevamente indicando patrones irregulares en la fase de balanceo de la marcha.
#
#
#
# 4. **Entropía vs SD (RSwing - Balanceo Derecho):**
#
#     Se observa una gran dispersión en los grupos con ALS y Huntington, mientras que los controles (en rojo) están más agrupados.
#
# Este gráfico permite evidenciar una relación positiva entre la entropía y la desviación estándar en enfermedades neurodegenerativas. En general, los pacientes con ALS y Huntington muestran que, a medida que aumenta la entropía (más desorden en la marcha), también aumenta la variabilidad (SD) de los pasos y balanceos. Esto puede ser porque estas enfermedades afectan la capacidad del sistema nervioso para regular y mantener patrones de marcha predecibles, lo que lleva a una marcha más caótica.
#
# En contraste, en los sujetos control, esta relación es menos evidente, ya que tanto la entropía como la SD son bajas, indicando que la marcha es estable y predecible. Entonces, podría resultar util analizar la relación entre SD y la entropía para un primer avistamiento hacia el diagnóstico o progreso de enfermedades neurológicas. En este contexto, si una persona tiene tanto una entropía alta como una SD alta en comparación con los controles, podría ser un signo de disfunción motora progresiva.

# %% [markdown]
# # Comparación de resultados con el artículo base [22]

# %% [markdown]
# Ambos análisis destacan que las enfermedades neurodegenerativas como ALS, Huntington y Parkinson afectan de manera significativa los patrones de marcha, con cada enfermedad mostrando alteraciones distintivas. La entropía, desviación estándar y coeficiente de variación confirman las alteraciones en la marcha descritas en el artículo base, y las observaciones sobre la heterocedasticidad y diferencias significativas entre los grupos refuerzan la necesidad de utilizar métricas que capturen la complejidad y variabilidad del movimiento en estas patologías.
#
# **1.	Coeficiente de Variación (CV)**
#
# El análisis realizado coincide con el artículo base respecto a los resultados en el coeficiente de variación, donde ambos determinan que este es significativamente mayor en pacientes con Huntington, indicando una mayor inestabilidad de la marcha. Además, se denota que ALS presenta un aumento en la variabilidad respecto a los controles, pero menor que en Huntington, y el CV en Parkinson también es mayor que en los controles, pero menos pronunciado que en ALS y Huntington.
#
# **2.	Desviación Estándar (SD)**
#
# En el artículo base, ALS presentaba un aumento en la variabilidad respecto a los controles, pero menor que en Huntington, lo que concuerda con las observaciones del análisis realizado, confirmando que la SD es un buen indicador de la variabilidad en la marcha. Huntington tiene la mayor SD, seguido por ALS y luego Parkinson.
#
# **3.	Entropía**
#
# La mayor entropía en ALS, seguida de Huntington y luego Parkinson, está en línea con los aumentos de complejidad y variabilidad observados en el artículo base, aunque este no discute directamente la entropía, reporta un aumento en la complejidad de las fluctuaciones y perturbaciones en la dinámica de la marcha en ALS. También describe cómo Huntington genera patrones caóticos, lo que se relaciona con la alta entropía en los resultados de este análisis.
#
# **4.	Heterocedasticidad**
#
# En el artículo base no se menciona específicamente la heterocedasticidad. Sin embargo, los patrones descritos para cada enfermedad en los que observan una variabilidad significativamente mayor en ALS, HD y PD en comparación con los controles, sugieren una variabilidad diferente entre grupos que se puede relacionar con las diferentes varianzas entre los grupos evaluados, lo cual indica diferentes impactos de cada enfermedad en la marcha.
#
# **5.	Comparación de Fases de Paso y Balanceo (Stride y Swing)**
#
# En el artículo base se menciona que ALS tiene afectaciones más significativas en el patrón de marcha que Parkinson, y que el grupo de pacientes con Huntington era el más afectado en términos de variabilidad. Esto concuerda con las diferencias significativas en la entropía y SD entre el grupo control y los pacientes con ALS, así como entre las tres enfermedades evaluadas.

# %% [markdown]
# # Medidas útiles para discriminar las poblaciones clínicas de los controles

# %% [markdown]
# En base a los resultados obtenidos, las medidas más útiles que podrían servir para discriminar entre las poblaciones clínicas (ALS, Huntington y Parkinson) y el grupo Control, son:
#
# 1. **Entropía (Ent)**
#
#     La entropía presenta una mayor dispersión en ALS (valores más bajos) en comparación con los controles, lo que sugiere una desorganización significativa en los patrones de marcha. Este hallazgo puede servir como un indicador clave para diferenciar entre estos grupos. Así mismo, se observaron diferencias entre ALS y Huntington o Parkinson. Sin embargo, no hay diferencias significativas entre Huntington y Parkinson, lo que indica que la entropía puede ser más efectiva para discriminar a ALS de los otros grupos.
#
#     Por otro lado, heterocedasticidad observada en la entropía sugiere que la variabilidad de marcha entre los grupos es diferente. Esto puede reforzar la idea de que esta medida es relevante para identificar y discriminar entre las poblaciones clínicas y controles.
#
#
# 2. **Desviación estándar (SD)**
#
#     La desviación estándar mostró diferencias significativas entre el grupo Control y los tres grupos clínicos en la fase de paso y balanceo. Los controles presentan valores bajos y consistentes, mientras que los pacientes con ALS, Huntington y Parkinson muestran variabilidad aumentada.
#
#     Aunque ALS, Huntington y Parkinson presentan variabilidad similar en algunas mediciones, la diferencia significativa entre Huntington y Parkinson en SD_RStride sugiere que esta métrica puede ayudar a distinguir entre estos dos grupos en la fase de marcha derecha.
#
#
# Estas medidas proporcionan un enfoque robusto para identificar diferencias en los patrones de marcha y pueden ser utilizadas para apoyar conclusiones sobre el impacto de las enfermedades neurodegenerativas en la marcha
#
# Es importante aclarar que, el coeficiente de variación parece tener un valor limitado como diferenciador entre el grupo de personas control y con enfermedades. Graficamente, se tiene que, la dispersión visual sugiere diferencias. Sin embargo, los gráficos pueden hacer que las diferencias parezcan más significativas de lo que realmente son en términos estadísticos. Esto se comprueba con las pruebas realizadas, las cuales muestran que dichas diferencias no son estadísticamente significativas, por lo que el CV no se considera un diferenciador robusto entre grupos, salvo en casos específicos como entre Parkinson y Huntington en la fase de marcha.

# %% [markdown]
# # Conclusiones

# %% [markdown]
# Las alteraciones en la marcha observadas en pacientes con enfermedades neurodegenerativas sugieren que su análisis puede ser una herramienta útil tanto para el diagnóstico temprano como para el seguimiento de la progresión de estas enfermedades. Cada patología estudiada muestra un patrón distintivo en las alteraciones de la marcha, lo que refleja la diversidad de los mecanismos patológicos subyacentes y su impacto en la locomoción, generando una heterogeneidad en los patrones de marcha.
#
# En este contexto, la entropía y la desviación estándar se caracterizan como las métricas más útiles para diferenciar entre las diversas patologías, mientras que el coeficiente de variación (CV) parece no aportar tanta información significativa en el análisis estadísico. En particular, los valores de CV son similares entre los grupos, lo que sugiere que puede no ser la mejor herramienta para detectar variabilidad en los patrones de marcha.
#
# Este análisis refuerza la idea de que las enfermedades neurodegenerativas como ALS, Huntington y Parkinson impactan notablemente la variabilidad y la irregularidad de la marcha, siendo la entropía y el coeficiente de variación mejores indicadores de estas alteraciones.

# %% [markdown]
# ## **Referecias**
#
# [1] Estrada-Bellmann, I., & Martínez Rodríguez, H. R. (s.f.). Diagnóstico y tratamiento de la enfermedad de Parkinson. Biblat - Bibliografía latinoamericana. https://biblat.unam.mx/hevila/Avances/2011/vol8/no25/3.pdf
#
# [2] Mejía Gallegos, A., Tobon, M. G., Guamán Mariscal, E., & Murillo Brunes, A. (s.f.). La enfermedad de Huntington, síntomas y tratamiento. Dialnet. https://dialnet.unirioja.es/servlet/articulo?codigo=9284141
#
# [3] Diagnóstico de la enfermedad de huntington. (s.f.). Roche Pacientes Nos Anticipamos a las Necesidades de los Pacientes | Roche Pacientes. https://rochepacientes.es/enfermedad-huntington/diagnostico.html
#
# [4] Acurio, P., & Latorre, M. (2024, 26 de julio). Diagnóstico y tratamiento de la esclerosis lateral amiotrófica | acurio padilla | revista información científica. Revista Información Científica. https://revinfcientifica.sld.cu/index.php/ric/article/view/4568/6227
#
# [5] Detrend — scipy v1.14.1 manual. (s.f.). Numpy and Scipy Documentation — Numpy and Scipy documentation. https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.detrend.html
#
# [6] Herbold, S. (2021, 11 de agosto). Time series analysis. Site not found · GitHub Pages. https://sherbold.github.io/intro-to-data-science/09_Time-Series-Analysis.html
#
# [7] Quintero-Rincon, Antonio & Liberczuk, Sergio & Risk, Marcelo. (2012). Preprocesamiento de EEG con Filtros Hampel. Argencon IEEE 2012. 89. https://www.researchgate.net/publication/232709754_Preprocesamiento_de_EEG_con_Filtros_Hampel
#
# [8] Hampel - Eliminar valores atípicos con un identificador Hampel - MATLAB- MathWorks América Latina. (s.f.). MathWorks - Creador de MATLAB y Simulink - MATLAB y Simulink - MATLAB & Simulink. https://la.mathworks.com/help/signal/ref/hampel.html
#
# [9] Bandt, C., & Pompe, B. (2002, 11 de abril). Permutation entropy: A natural complexity measure for time series. Physical Review Letters. https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.88.174102
#
# [10] Antonelli, A. P. (s.f.). Entropía de permutación para la caracterización de texturas en imágenes digitales. RINFI. https://rinfi.fi.mdp.edu.ar/xmlui/bitstream/handle/123456789/267/APAntonelli-TFG-IEe-2017.pdf?sequence=1&amp;isAllowed=y
#
# [11] Lledó, A. (s.f.). Alteraciones de la marcha: Qué es, síntomas y tratamiento | Top Doctors. Top Doctors. https://www.topdoctors.es/diccionario-medico/alteraciones-de-la-marcha#:~:text=La%20marcha%20tiene%20lugar%20siguiendo,la%20marcha%20y%20el%20equilibrio.
#
# [12] Guía N° 4 entropía. (s.f.). https://www7.uc.cl/sw_educ/educacion/grecia/plano/html/pdfs/cra/fisica/NM4/RFE4T_003.pdf
#
# [13] Medidas de variación: Rango, desviación estándar y coeficiente de variación. (s.f.). RI UAEMex. http://ri.uaemex.mx/oca/view/20.500.11799/32031/1/secme-21225.pdf
#
# [14] Diagrama de violí­n. (s.f.). The Data Visualisation Catalogue. https://datavizcatalogue.com/ES/metodos/diagrama_de_violin.html
#
# [15] Mobility and ALS. (s.f.). The ALS Association. https://www.als.org/navigating-als/living-with-als/therapies-care/mobility-als
#
# [16] Berke Erdaş, Ç. (2023, 18 de febrero). Neurodegenerative diseases detection and grading using gait dynamics - Multimedia Tools and Applications. SpringerLink. https://link.springer.com/article/10.1007/s11042-023-14461-7
#
# [17] RPubs - Prueba de normalidad de Shapiro-Wilk. (s.f.). RPubs. https://rpubs.com/F3rnando/507482
#
# [18] T-Test, chi-square, ANOVA, regression, correlation... (s.f.). Calculadora estadí­stica en línea: Pruebas de hipótesis, prueba t, chi-cuadrado, regresión, correlación, análisis de varianza, análisis de conglomerados. https://datatab.es/tutorial/levene-test
#
# [19] SPSS statistics subscription - early access. (s.f.). IBM - United States. https://www.ibm.com/docs/es/spss-statistics/beta?topic=tests-mann-whitney-u-test
#
# [20] Pedrosa, S. J. (2017, 12 de junio). Heterocedasticidad. Economipedia. https://economipedia.com/definiciones/heterocedasticidad.html
#
# [21] Gráfico de dispersión. (s.f.). jmp statistical discovery. https://www.jmp.com/es_co/statistics-knowledge-portal/exploratory-data-analysis/scatter-plot.html
#
# [22] J. M. Hausdorff, A. Lertratanakul, M. E. Cudkowjcz y A. L. Peterson. “Dynamic markers of altered gait rhythm in amyotrophic lateral sclerosis”. American physiological society. Accedido el 21 de septiembre de 2024. Disponible: https://journals.physiology.org/doi/full/10.1152/jappl.2000.88.6.2045
